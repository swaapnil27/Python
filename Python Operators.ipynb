# %% [markdown]
# ### Python Operators

# %% [markdown]
# ### Arithmetic Operator**

# %% [markdown]
# ![python-arithmetic-operators.jpg](attachment:python-arithmetic-operators.jpg)

# %%
a = 10
b = 3

# %%
print("a + b = ", a + b)
print("a - b = ", a - b)
print("a * b = ", a * b)
print("a / b = ", a / b)
# Out:
# a + b =  13
# a - b =  7
# a * b =  30
# a / b =  3.3333333333333335

# %%
print("a // b = ", a // b) ## Floor devision
# Out:
# a // b =  3

# %% [markdown]
# **Modulus (mod) operator**
#
#
# remainder shown

# %%
25 % 4
# Out:
# 1

# %%
10 % 5
# Out:
# 0

# %% [markdown]
# **Exponential**

# %%
print('a ** b= ',a ** b)
# Out:
# a ** b=  1000

# %% [markdown]
# **Comparision Operator**

# %% [markdown]
# ![Python_Comparison_Operator_.png](attachment:Python_Comparison_Operator_.png)

# %%
a == b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a != 2
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
a >= b
# Out:
# True

# %% [markdown]
# **Logical Operators**

# %% [markdown]
# and, or ,not

# %%
(a == 10) and (b == 3)
# Out:
# True

# %%
(a == 10) and (b == 5)
# Out:
# False

# %%
(a == 10) or (b == 5)   ## any condition evaluating True then entire result will be True
# Out:
# True

# %%
not(a < 12)
# Out:
# False

# %% [markdown]
# **Python Identity Operator**

# %%
print(a,b)
# Out:
# 10 3

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
c = 10

# %%
a is c
# Out:
# True

# %% [markdown]
# **Python Membership Operator**

# %%
string = "Hello Friends, Good Morning "

# %%
"Morning" in string
# Out:
# True

# %%
"morning" in string   ## Case sensetive
# Out:
# False

# %%
"afternoon"  not in string
# Out:
# True

# %% [markdown]
# **Assignment Operator**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(a)
# Out:
# 10

# %%
a += 1

# %%
print(a)
# Out:
# 11

# %%
a *= 2
a
# Out:
# 22

# %% [markdown]
# **Python Bitwise operators**

# %%
# & (And)
# | (Or)
# ^ (xor)
# ~ (Not)

# %%
a = 20
b = 5

# %%
a & b
# Out:
# 4

# %%
#Binary of 
bin(20)
# Out:
# '0b10100'

# %%
bin(5)
# Out:
# '0b101'

# %%
a | b
# Out:
# 21

# %%
bin(21)
# Out:
# '0b10101'

# %%
bin?
